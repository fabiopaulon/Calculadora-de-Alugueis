# %%
#Imports:

import requests
from bs4 import BeautifulSoup
import pandas as pd
from time import sleep
import numpy as np
import re

# %%
c = requests.get('https://imoveis.mercadolivre.com.br/aluguel/').content

# %%
zonas = ['norte','sul','leste','oeste']
URL='https://imoveis.mercadolivre.com.br/casas/aluguel/sao-paulo/sao-paulo-zona-{}/{}'
paginas=['', '_Desde_49', '_Desde_97', '_Desde_145', '_Desde_193', 
           '_Desde_241', '_Desde_289']

# %%
# Functions
def scrap(url):
    c=requests.get(url).content
    soup=BeautifulSoup(c)
    aluguel_tags = soup.find_all('span', {'class':'price-tag-fraction'})
    alugueis_lista = [p.text for p in aluguel_tags]
    enderecos_tags = soup.find_all('span', {'class':'ui-search-item__group__element'})
    enderecos_lista=[end.text for end in enderecos_tags]
    enderecos_lista=enderecos_lista[1::2]
    area_quartos_tags = soup.find_all('ul', {'class':'ui-search-card-attributes'})
    area_quartos_lista=[aq.text for aq in area_quartos_tags]
    df=convert_df(zona, area_quartos_lista, enderecos_lista, alugueis_lista)
    return df

def convert_df(zona, area_quartos_lista, enderecos_lista, alugueis_lista):
    zonas_lista = [zona]*len(alugueis_lista)
    data = {'zona': zonas_lista,
            'area_quartos': area_quartos_lista,
            'enderecos_lista':enderecos_lista,
            'aluguel': alugueis_lista}
    df = pd.DataFrame(data)
    return df

# %%
lista_dfs = []
for zona in zonas:
    for pg in paginas:
        url='https://imoveis.mercadolivre.com.br/aluguel/sao-paulo/sao-paulo-zona-{}/{}'.format(zona, pg)
        print(url)
        df=scrap(url)
        lista_dfs.append(df)
        sleep(1)
# Out:
# https://imoveis.mercadolivre.com.br/aluguel/sao-paulo/sao-paulo-zona-norte/
# https://imoveis.mercadolivre.com.br/aluguel/sao-paulo/sao-paulo-zona-norte/_Desde_49
# https://imoveis.mercadolivre.com.br/aluguel/sao-paulo/sao-paulo-zona-norte/_Desde_97
# https://imoveis.mercadolivre.com.br/aluguel/sao-paulo/sao-paulo-zona-norte/_Desde_145
# https://imoveis.mercadolivre.com.br/aluguel/sao-paulo/sao-paulo-zona-norte/_Desde_193
# https://imoveis.mercadolivre.com.br/aluguel/sao-paulo/sao-paulo-zona-norte/_Desde_241
# https://imoveis.mercadolivre.com.br/aluguel/sao-paulo/sao-paulo-zona-norte/_Desde_289
# https://imoveis.mercadolivre.com.br/aluguel/sao-paulo/sao-paulo-zona-sul/
# https://imoveis.mercadolivre.com.br/aluguel/sao-paulo/sao-paulo-zona-sul/_Desde_49
# https://imoveis.mercadolivre.com.br/aluguel/sao-paulo/sao-paulo-zona-sul/_Desde_97
# https://imoveis.mercadolivre.com.br/aluguel/sao-paulo/sao-paulo-zona-sul/_Desde_145
# https://imoveis.mercadolivre.com.br/aluguel/sao-paulo/sao-paulo-zona-sul/_Desde_193
# https://imoveis.mercadolivre.com.br/aluguel/sao-paulo/sao-paulo-zona-sul/_Desde_241
# https://imoveis.mercadolivre.com.br/aluguel/sao-paulo/sao-paulo-zona-sul/_Desde_289
# https://imoveis.mercadolivre.com.br/aluguel/sao-paulo/sao-paulo-zona-leste/
# https://imoveis.mercadolivre.com.br/aluguel/sao-paulo/sao-paulo-zona-leste/_Desde_49
# https://imoveis.mercadolivre.com.br/aluguel/sao-paulo/sao-paulo-zona-leste/_Desde_97
# https://imoveis.mercadolivre.com.br/aluguel/sao-paulo/sao-paulo-zona-leste/_Desde_145
# https://imoveis.mercadolivre.com.br/aluguel/sao-paulo/sao-paulo-zona-leste/_Desde_193
# https://imoveis.mercadolivre.com.br/aluguel/sao-paulo/sao-paulo-zona-leste/_Desde_241
# https://imoveis.mercadolivre.com.br/aluguel/sao-paulo/sao-paulo-zona-leste/_Desde_289
# https://imoveis.mercadolivre.com.br/aluguel/sao-paulo/sao-paulo-zona-oeste/
# https://imoveis.mercadolivre.com.br/aluguel/sao-paulo/sao-paulo-zona-oeste/_Desde_49
# https://imoveis.mercadolivre.com.br/aluguel/sao-paulo/sao-paulo-zona-oeste/_Desde_97
# https://imoveis.mercadolivre.com.br/aluguel/sao-paulo/sao-paulo-zona-oeste/_Desde_145
# https://imoveis.mercadolivre.com.br/aluguel/sao-paulo/sao-paulo-zona-oeste/_Desde_193
# https://imoveis.mercadolivre.com.br/aluguel/sao-paulo/sao-paulo-zona-oeste/_Desde_241
# https://imoveis.mercadolivre.com.br/aluguel/sao-paulo/sao-paulo-zona-oeste/_Desde_289

# %%
df=pd.concat(lista_dfs)
df.head()
# Out:
#     zona                area_quartos  \
# 0  norte   35 m² construídos1 quarto
# 1  norte  50 m² construídos2 quartos
# 2  norte  74 m² construídos3 quartos
# 3  norte        7,800 m² construídos
# 4  norte  94 m² construídos2 quartos
#
#                                      enderecos_lista aluguel
# 0  Rua Yvorne, Lauzane Paulista, São Paulo Zona N...     930
# 1  Rua Aburá, Sítio Do Mandaqui, São Paulo Zona N...     940
# 2  Rua José Ataliba Ortiz, Vila Mangalot, São Pau...   2.900
# 3  Vila Nova Galvão, São Paulo Zona Norte, São Paulo  27.000
# 4  Rua Amândio Monteiro, Vila Guilherme, São Paul...   1.300

# %%
df.to_csv('dados_aluguel_ml_sao_paulo.csv', index=False)

# %%
# Funções
def extrair_area(entrada):
  """Criar função que possua como entrada um texto e retorne a área contida no
  mesmo. Retornar np.nan se for ausentes. Alguns exemplos:
      >>> extrair_area('79 m² construídos1 quarto')
      >>> 79
      >>> extrair_area('280 m² construídos')
      >>> 280
      >>> extrair_area('2,600 m² construídos'
      >>> 2600
      >>> extrair_area('2 quartos')
      >>> np.nan
      """
  if ' m²' in entrada:
    area = entrada.split(' m²')[0]
    area = area.replace(',', '')
  else:
    area = np.nan
  return area

def extrair_quartos(entrada):
  """Criar função que possua como entrada um texto e retorne uma tupla com a 
  área e o quarto. Retornar np.nan se um dos dois for ausentes. Alguns exemplos:
      >>> extrair_quarto('79 m² construídos1 quarto')
      >>> 1
      >>> extrair_quarto('280 m² construídos')
      >>> np.nan
      >>> extrair_quarto('2,600 m² construídos'
      >>> np.nan
      >>> extrair_quarto('2 quartos')
      >>> 2"""
  if 'quarto' in entrada:
    n_quartos = re.findall('(\d*) quarto', entrada)[0]
  else:
    n_quartos = np.nan
  return n_quartos

# %%
df['area']=df['area_quartos'].apply(extrair_area).astype(float)
df['quartos'] = df['area_quartos'].apply(extrair_quartos).astype(float)

df = df.drop('area_quartos', axis=1)
df.head()
# Out:
#     zona                                    enderecos_lista aluguel    area  \
# 0  norte  Rua Yvorne, Lauzane Paulista, São Paulo Zona N...     930    35.0
# 1  norte  Rua Aburá, Sítio Do Mandaqui, São Paulo Zona N...     940    50.0
# 2  norte  Rua José Ataliba Ortiz, Vila Mangalot, São Pau...   2.900    74.0
# 3  norte  Vila Nova Galvão, São Paulo Zona Norte, São Paulo  27.000  7800.0
# 4  norte  Rua Amândio Monteiro, Vila Guilherme, São Paul...   1.300    94.0
#
#    quartos
# 0      1.0
# 1      2.0
# 2      3.0
# 3      NaN
# 4      2.0

# %%
for i in range(0,20):
    print(df.iloc[i]['enderecos_lista'])
# Out:
# Rua Yvorne, Lauzane Paulista, São Paulo Zona Norte, São Paulo
# Rua Aburá, Sítio Do Mandaqui, São Paulo Zona Norte, São Paulo
# Rua José Ataliba Ortiz, Vila Mangalot, São Paulo Zona Norte, São Paulo
# Vila Nova Galvão, São Paulo Zona Norte, São Paulo
# Rua Amândio Monteiro, Vila Guilherme, São Paulo Zona Norte, São Paulo
# Rua Jaguarete, Casa Verde, São Paulo Zona Norte, São Paulo
# Rua Nicolau Tolentino De Almeida, Vila Dionisia, São Paulo Zona Norte, São Paulo
# Rua Manoel Martins Da Rocha, Vila Mangalot, São Paulo Zona Norte, São Paulo
# Rua Itaxama, Vila Mangalot, São Paulo Zona Norte, São Paulo
# Tucuruvi, São Paulo Zona Norte, São Paulo
# Rua José De Almeida, Vila Medeiros, São Paulo Zona Norte, São Paulo
# Avenida General Penha Brasil, Vila Nova Cachoeirinha, São Paulo Zona Norte, São Paulo
# Rua Manguari, Jardim Andaraí, São Paulo Zona Norte, São Paulo
# Rua Manoel Martins Da Rocha, Vila Mangalot, São Paulo Zona Norte, São Paulo
# Rua Epaminondas Melo Do Amaral, Sítio Do Mandaqui, São Paulo Zona Norte, São Paulo
# Rua Francisco Shigueki Nomura, Imirim, São Paulo Zona Norte, São Paulo
# Rua Yvorne, Lauzane Paulista, São Paulo Zona Norte, São Paulo
# Vila Nilo, São Paulo Zona Norte, São Paulo
# Rua Yvorne, Lauzane Paulista, São Paulo Zona Norte, São Paulo
# Rua Tanque Velho, Vila Nivi, São Paulo Zona Norte, São Paulo

# %%
df.head()
# Out:
#     zona                                    enderecos_lista aluguel    area  \
# 0  norte  Rua Yvorne, Lauzane Paulista, São Paulo Zona N...     930    35.0
# 1  norte  Rua Aburá, Sítio Do Mandaqui, São Paulo Zona N...     940    50.0
# 2  norte  Rua José Ataliba Ortiz, Vila Mangalot, São Pau...   2.900    74.0
# 3  norte  Vila Nova Galvão, São Paulo Zona Norte, São Paulo  27.000  7800.0
# 4  norte  Rua Amândio Monteiro, Vila Guilherme, São Paul...   1.300    94.0
#
#    quartos
# 0      1.0
# 1      2.0
# 2      3.0
# 3      NaN
# 4      2.0

# %%
df[(df['quartos'].isnull()) & (df['zona'] == 'norte')].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 3 to 29
# Data columns (total 5 columns):
# zona               15 non-null object
# enderecos_lista    15 non-null object
# aluguel            15 non-null object
# area               15 non-null float64
# quartos            0 non-null float64
# dtypes: float64(2), object(3)
# memory usage: 720.0+ bytes

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1321 entries, 0 to 47
# Data columns (total 5 columns):
# zona               1321 non-null object
# enderecos_lista    1321 non-null object
# aluguel            1321 non-null object
# area               1320 non-null float64
# quartos            1265 non-null float64
# dtypes: float64(2), object(3)
# memory usage: 61.9+ KB
#     zona                                    enderecos_lista aluguel    area  \
# 0  norte  Rua Yvorne, Lauzane Paulista, São Paulo Zona N...     930    35.0
# 1  norte  Rua Aburá, Sítio Do Mandaqui, São Paulo Zona N...     940    50.0
# 2  norte  Rua José Ataliba Ortiz, Vila Mangalot, São Pau...   2.900    74.0
# 3  norte  Vila Nova Galvão, São Paulo Zona Norte, São Paulo  27.000  7800.0
# 4  norte  Rua Amândio Monteiro, Vila Guilherme, São Paul...   1.300    94.0
#
#    quartos
# 0      1.0
# 1      2.0
# 2      3.0
# 3      NaN
# 4      2.0

# %%
df['aluguel'].shape
# Out:
# (1344,)

# %%
#convertendo aluguel para o formato float

df['aluguel'] = df['aluguel'].iloc[:].str.replace('.', '').astype(float)

df['aluguel'].head(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-1aaee6087c8a> in <module>
#       1 #convertendo aluguel para o formato float
#       2
# ----> 3 df['aluguel'] = df['aluguel'].iloc[:].str.replace('.', '').astype(float)
#       4
#       5 df['aluguel'].head(10)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5173             or name in self._accessors
#    5174         ):
# -> 5175             return object.__getattribute__(self, name)
#    5176         else:
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\Anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     173             # we're accessing the attribute of the class, i.e., Dataset.geo
#     174             return self._accessor
# --> 175         accessor_obj = self._accessor(obj)
#     176         # Replace the property with the accessor object. Inspired by:
#     177         # http://www.pydanny.com/cached-property.html
#
# ~\Anaconda3\lib\site-packages\pandas\core\strings.py in __init__(self, data)
#    1915
#    1916     def __init__(self, data):
# -> 1917         self._inferred_dtype = self._validate(data)
#    1918         self._is_categorical = is_categorical_dtype(data)
#    1919
#
# ~\Anaconda3\lib\site-packages\pandas\core\strings.py in _validate(data)
#    1965
#    1966         if inferred_dtype not in allowed_types:
# -> 1967             raise AttributeError("Can only use .str accessor with string " "values!")
#    1968         return inferred_dtype
#    1969
#
# AttributeError: Can only use .str accessor with string values!

# %%
for zona in zonas:
    print('Dados de quartos faltantes da zona   {} x dados totais da mesma zona'.format(zona))
    print(df[(df['quartos'].isnull()) & (df['zona'] == zona)].describe())
    print(df[df['zona'] == zona].describe())
# Out:
# Dados de quartos faltantes da zona   norte x dados totais da mesma zona
#             aluguel         area  quartos
# count     15.000000    15.000000      0.0
# mean   16942.333333  1141.533333      NaN
# std    18077.396785  1965.833079      NaN
# min      950.000000    23.000000      NaN
# 25%     5500.000000   250.000000      NaN
# 50%    14000.000000   525.000000      NaN
# 75%    20500.000000   817.000000      NaN
# max    75000.000000  7800.000000      NaN
#             aluguel         area     quartos
# count    313.000000   313.000000  298.000000
# mean    2561.706070   124.444089    1.976510
# std     5126.178925   478.178432    0.780304
# min      500.000000    15.000000    1.000000
# 25%     1200.000000    48.000000    1.000000
# 50%     1600.000000    58.000000    2.000000
# 75%     2300.000000    80.000000    2.000000
# max    75000.000000  7800.000000    6.000000
# Dados de quartos faltantes da zona   sul x dados totais da mesma zona
#        aluguel  area  quartos
# count      0.0   0.0      0.0
# mean       NaN   NaN      NaN
# std        NaN   NaN      NaN
# min        NaN   NaN      NaN
# 25%        NaN   NaN      NaN
# 50%        NaN   NaN      NaN
# 75%        NaN   NaN      NaN
# max        NaN   NaN      NaN
#             aluguel        area     quartos
# count    336.000000  336.000000  336.000000
# mean    3050.122024   72.229167    1.836310
# std     1869.734338   47.761889    0.853434
# min      625.000000   13.000000    1.000000
# 25%     1865.000000   42.000000    1.000000
# 50%     2599.500000   61.500000    2.000000
# 75%     3550.000000   85.000000    2.000000
# max    15000.000000  500.000000    4.000000
# Dados de quartos faltantes da zona   leste x dados totais da mesma zona
#             aluguel         area  quartos
# count     27.000000    27.000000      0.0
# mean    9227.814815   579.925926      NaN
# std    12850.730018   847.747419      NaN
# min      900.000000    25.000000      NaN
# 25%     1475.000000    39.000000      NaN
# 50%     3500.000000   156.000000      NaN
# 75%    11000.000000   775.000000      NaN
# max    55000.000000  3150.000000      NaN
#             aluguel         area     quartos
# count    336.000000   335.000000  309.000000
# mean    2549.348214   117.967164    2.009709
# std     4353.272641   279.690283    0.884518
# min        1.000000     6.000000    1.000000
# 25%     1100.000000    44.000000    1.000000
# 50%     1537.500000    56.000000    2.000000
# 75%     2400.000000    91.500000    2.000000
# max    55000.000000  3150.000000    7.000000
# Dados de quartos faltantes da zona   oeste x dados totais da mesma zona
#              aluguel         area  quartos
# count      14.000000    14.000000      0.0
# mean    25196.428571   808.000000      NaN
# std     47189.309677  1341.995357      NaN
# min       900.000000    30.000000      NaN
# 25%      5225.000000   211.250000      NaN
# 50%      7500.000000   297.000000      NaN
# 75%     17250.000000   550.000000      NaN
# max    169000.000000  4536.000000      NaN
#              aluguel         area     quartos
# count     336.000000   336.000000  322.000000
# mean     3942.785714   106.404762    1.894410
# std     10531.547468   308.562517    0.980193
# min       600.000000    15.000000    1.000000
# 25%      1600.000000    39.750000    1.000000
# 50%      2350.000000    60.000000    2.000000
# 75%      3792.500000    95.000000    2.000000
# max    169000.000000  4536.000000    8.000000

# %% [markdown]
# *** Primeira conclusão: Quando não está disponível a informação do número de quarto, geralmente é um imóvel com área e preço superior à média. Os outliers de cada zona coincidentemente não tem a informação do número de quartos também.
#
# *** Estratégia: drop NaN

# %%
df.dropna(inplace=True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1264 entries, 0 to 47
# Data columns (total 5 columns):
# zona               1264 non-null object
# enderecos_lista    1264 non-null object
# aluguel            1264 non-null float64
# area               1264 non-null float64
# quartos            1264 non-null float64
# dtypes: float64(3), object(2)
# memory usage: 59.2+ KB

# %% [markdown]
# # Feature Engineering
# Coletando dados de latitude e longitude

# %%
from geopy.geocoders import Nominatim

# %%
geolocator = Nominatim(user_agent="fabio_paulon")
location = geolocator.geocode("rua Av Virgília Rodrigues Alves De Carvalho Pinto Sao Paulo
")
print((location.latitude, location.longitude))
# Out:
#   File "<ipython-input-26-c5d3e91c4325>", line 2
#     location = geolocator.geocode("rua Av Virgília Rodrigues Alves De Carvalho Pinto Sao Paulo
#                                                                                               ^
# SyntaxError: EOL while scanning string literal

# %%
for i in range(0,20):
    print(geolocator.geocode(df.iloc[i]['enderecos_lista'.split(',')[0]", São Paulo")]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-183-86fbb9fe736b> in <module>
#       1 for i in range(0,20):
# ----> 2     print(geolocator.geocode(df.iloc[i]['enderecos_lista'.split(',')[0].concat(", São Paulo")]))
#
# AttributeError: 'str' object has no attribute 'concat'

# %%
df.to_csv('dados_aluguel_ml_sao_paulo_preprocessado.csv', index=False)

# %%
df['rua'] = df['enderecos_lista'].str.split(',')

# %%
df['rua']= df['rua'].map(lambda x: x[0])

# %%
df['rua'] = 'rua '+ df['rua'] + ' Sao Paulo'

# %%
df['rua']
# Out:
# 0                        rua Rua Yvorne Sao Paulo
# 1                         rua Rua Aburá Sao Paulo
# 2            rua Rua José Ataliba Ortiz Sao Paulo
# 4              rua Rua Amândio Monteiro Sao Paulo
# 5                     rua Rua Jaguarete Sao Paulo
#                          ...
# 43      rua Avenida José Joaquim Seabra Sao Paulo
# 44    rua Rua Doutor Cândido Espinheira Sao Paulo
# 45             rua Rua Ricardo Cavatton Sao Paulo
# 46                  rua Avenida Jaguaré Sao Paulo
# 47     rua Antonio De Almeida Naves 326 Sao Paulo
# Name: rua, Length: 1264, dtype: object

# %%
for rua in df['rua'].values:
    try: 
        print(geolocator.geocode(rua).latitude)
    except:
        np.nan()
# Out:
# -23.47203
# -23.4850058
# -23.4998993
# -23.5032118
# -23.195376
# -23.4679021
# -23.4872494
# -23.5063353
# -23.4922213
# -23.4693554
# -23.5241575
# -23.4872494
# -23.490515
# -23.4891558
# -23.47203
# -23.47203
# -23.4789442
# -23.4807254
# -23.5038827
# -23.492065
# -23.4667598
# -23.4943876
# -23.4973983
# -23.4821485
# -23.47203
# -23.4920807
# -23.4935462
# -23.5171958
# -23.4966867
# -23.492065
# -23.5250058
# -23.5008856
# -23.4475728
# -23.5250058
# -23.5528101
# -23.4704017
# -23.5009501
# -23.5448774
# -23.4956739
# -23.5005837
# -23.5119687
# -23.4750027
# -23.4975077
# -23.4913009
# -23.5031043
# -23.492065
# -23.5034547
# -23.4975077
# -23.484777
# -23.5162077
# -23.4748394
# -23.47203
# -23.47203
# -23.47203
# -23.4973053
# -23.4907201
# -23.195376
# -22.75314995
# erro ocorreu em:
# rua Av Virgília Rodrigues Alves De Carvalho Pinto Sao Paulo
# -23.4941359
# -23.5127291
# -23.4756894
# -23.6409056
# -23.4854511
# -23.4977555
# -23.5109971
# -23.5038827
# -23.4704017
# -23.5025533
# -23.4869073
# -23.4958982
# -23.5086427
# -23.550389799999998
# -23.4993126
# -23.4969139
# -23.4638614
# -23.4975077
# -23.506996
# -23.4826588
# -23.4909516
# -23.4927179
# -23.4915641
# erro ocorreu em:
# rua Rua Alexandre Danel Sao Paulo
# -23.5509552
# -23.5620814
# -23.4966518
# -23.5564624
# -23.56744425
# -23.5638126
# -23.4974837
# -23.4351151
# -23.5970985
# -23.5572937
# -23.5972165
# -23.5652616
# -23.6061205
# -23.518826
# -23.6009124
# -23.5211583
# -23.5068355
# -23.5476999
# -23.4861494
# -23.6000381
# -23.5081309
# -23.5877102
# -23.9468443
# -23.5488477
# -23.5464909
# -23.4983654
# -23.5585094
# -23.5352528
# -23.5380765
# -23.5272316
# -23.550382
# -23.5872006
# -23.5301519
# -21.1248242
# -23.4962243
# -23.5540285
# -23.6033291
# -23.521938
# -23.5463689
# -23.5045438
# -23.5654527
# -23.5028431
# -23.5547162
# -23.6232587
# -23.5844456
# erro ocorreu em:
# rua Rua Adolfo Celi Sao Paulo
# -23.5846436
# -23.5977011
# -23.5534455
# -23.5164813
# -23.5364677
# -23.5774879
# erro ocorreu em:
# rua Rua São Giu Sao Paulo
# -23.5556964
# -23.5877371
# -23.5438441
# -23.5875709
# -23.6030682
# erro ocorreu em:
# rua Rua Henrique De Sousa Queirós Sao Paulo
# -23.6385019
# -23.5383777
# -23.5265264
# -23.5569801
# -23.5538549
# -23.5283935
# erro ocorreu em:
# rua Rua Lucila Faria Sao Paulo
# -23.5548398
# -23.550446
# -23.517743
# -23.5867126
# -23.5771376
# -23.5302804
# -23.5722418
# -23.5927497
# -23.5393049
# -23.5283935
# -23.5414891
# -23.55507
# -23.4914173
# -23.592314
# -23.5283935
# -23.5264513
# -23.5634614
# -23.5380765
# -23.6325566
# -23.5358333
# -23.5538335
# -23.5695225
# -23.5570655
# -23.5114806
# -23.5460495
# -24.0184433
# -23.588729

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="fabio_paulon")

def obter_latitude(rua):
    location = geolocator.geocode(rua)
    try: 
        latitude = location.latitude
    except:
        latitude = np.nan
    return latitude
        
def obter_longitude(rua):    
    location = geolocator.geocode(rua)
    try: 
        longitude = location.longitude
    except:
        longitude = np.nan
    return longitude

# %%
df['latitude']=df['rua'].apply(obter_latitude).astype(float)
df['longitude'] = df['rua'].apply(obter_longitude).astype(float)

# %%
df.head()
# Out:
#     zona                                    enderecos_lista  aluguel  area  \
# 0  norte  Rua Yvorne, Lauzane Paulista, São Paulo Zona N...    930.0  35.0
# 1  norte  Rua Aburá, Sítio Do Mandaqui, São Paulo Zona N...    940.0  50.0
# 2  norte  Rua José Ataliba Ortiz, Vila Mangalot, São Pau...   2900.0  74.0
# 4  norte  Rua Amândio Monteiro, Vila Guilherme, São Paul...   1300.0  94.0
# 5  norte  Rua Jaguarete, Casa Verde, São Paulo Zona Nort...   1650.0  61.0
#
#    quartos                                   rua   latitude  longitude
# 0      1.0              rua Rua Yvorne Sao Paulo -23.472030 -46.642959
# 1      2.0               rua Rua Aburá Sao Paulo -23.485006 -46.662995
# 2      3.0  rua Rua José Ataliba Ortiz Sao Paulo -23.499899 -46.743401
# 4      2.0    rua Rua Amândio Monteiro Sao Paulo -23.503212 -46.599148
# 5      2.0           rua Rua Jaguarete Sao Paulo -23.195376 -45.882711
